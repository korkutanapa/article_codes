# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
from numpy import mean
from numpy import std
from sklearn.compose import make_column_selector as selector
from sklearn.cross_decomposition import PLSRegression
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.feature_selection import RFE
from sklearn.linear_model import ElasticNetCV, ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import pandas as pd
from string import ascii_letters
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from genetic_selection import GeneticSelectionCV
import time
from xgboost import XGBRegressor
import joblib

# %%
a = [2400,2600,2800,3000,3200]
b = [22,24,26,28,30,32]
c = [4.4,5,5.5]
d = [30,32,36,38,40,45]
e = [40,42,44,46,50]
f = [5,10,15]
g = [41,43,45,50,60,80]

apt= pd.DataFrame(columns=['1PWRPM','1PWLower_Spray_Circulation_Period','1PWWaterInlet','2MWLower_Spray_Circulation_Period',
                          '2MWPeriod','4CRUpper_Spray_Circulation_Period','10DYPeriod'])
st = time.time()  
for aa in a:
        for bb in b:
            for cc in c:
                for dd in d:
                    for ee in e:
                            for ff in f:
                                for gg in g:
                                        new_row = pd.DataFrame({
                                                                '1PWRPM':aa,
                                                                '1PWLower_Spray_Circulation_Period':bb,
                                                                '1PWWaterInlet':cc,
                                                                '2MWLower_Spray_Circulation_Period':dd,
                                                                '2MWPeriod':ee,
                                                                '4CRUpper_Spray_Circulation_Period':ff,
                                                                '10DYPeriod':gg 
                                                                }, index=[0])                                                   
                                        apt = pd.concat([new_row,apt.loc[:]]).reset_index(drop=True)
et = time.time()
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')
# Out:
# Execution time: 276.0450942516327 seconds

# %%
apt
# Out:
#       1PWRPM 1PWLower_Spray_Circulation_Period  1PWWaterInlet  \
# 0       3200                                32            5.5
# 1       3200                                32            5.5
# 2       3200                                32            5.5
# 3       3200                                32            5.5
# 4       3200                                32            5.5
# ...      ...                               ...            ...
# 48595   2400                                22            4.4
# 48596   2400                                22            4.4
# 48597   2400                                22            4.4
# 48598   2400                                22            4.4
# 48599   2400                                22            4.4
#
#       2MWLower_Spray_Circulation_Period 2MWPeriod  \
# 0                                    45        50
# 1                                    45        50
# 2                                    45        50
# 3                                    45        50
# 4                                    45        50
# ...                                 ...       ...
# 48595                                30        40
# 48596                                30        40
# 48597                                30        40
# 48598                                30        40
# 48599                                30        40
#
#       4CRUpper_Spray_Circulation_Period 10DYPeriod
# 0                                    15         80
# 1                                    15         60
# 2                                    15         50
# 3                                    15         45
# 4                                    15         43
# ...                                 ...        ...
# 48595                                 5         60
# 48596                                 5         50
# 48597                                 5         45
# 48598                                 5         43
# 48599                                 5         41
#
# [48600 rows x 7 columns]

# %%
apt.to_excel('lastcycle.xlsx')

# %%
df_ref = pd.read_excel('D:/Users/ar600780/OneDrive - ARÇELİK A.Ş/Desktop/dataset_elsevier/dbso60sort.xlsx')

# %%
indvar=['1PWClosed_Cycle_Period',
'1PWPeriod',
'1PWCirculation_Period',
'1PWWaterInlet',
'1PWRPM',
'1PWTemperature',
'1PWLower_Spray_Circulation_Period',
'1PWUpper_Spray_Circulation_Period',
'1PWTop_Spray_Circulation_Period',
'1PWZone_Spray_Circulation_Period',
'1PWWaiting',
'1PWFan',
'1PWDoor_Openening',
'1PWFan_Flap',
'1PWExtra_Heater_Offset',
'1PWExtra_Heater_Nonoffset',
'2MWClosed_Cycle_Period',
'2MWPeriod',
'2MWCirculation_Period',
'2MWWaterInlet',
'2MWRPM',
'2MWTemperature',
'2MWLower_Spray_Circulation_Period',
'2MWUpper_Spray_Circulation_Period',
'2MWTop_Spray_Circulation_Period',
'2MWZone_Spray_Circulation_Period',
'2MWWaiting',
'2MWFan',
'2MWDoor_Openening',
'2MWFan_Flap',
'2MWExtra_Heater_Offset',
'2MWExtra_Heater_Nonoffset',
'3MFClosed_Cycle_Period',
'3MFPeriod',
'3MFCirculation_Period',
'3MFWaterInlet',
'3MFRPM',
'3MFTemperature',
'3MFLower_Spray_Circulation_Period',
'3MFUpper_Spray_Circulation_Period',
'3MFTop_Spray_Circulation_Period',
'3MFZone_Spray_Circulation_Period',
'3MFWaiting',
'3MFFan',
'3MFDoor_Openening',
'3MFFan_Flap',
'3MFExtra_Heater_Offset',
'3MFExtra_Heater_Nonoffset',
'4CRClosed_Cycle_Period',
'4CRPeriod',
'4CRCirculation_Period',
'4CRWaterInlet',
'4CRRPM',
'4CRTemperature',
'4CRLower_Spray_Circulation_Period',
'4CRUpper_Spray_Circulation_Period',
'4CRTop_Spray_Circulation_Period',
'4CRZone_Spray_Circulation_Period',
'4CRWaiting',
'4CRFan',
'4CRDoor_Openening',
'4CRFan_Flap',
'4CRExtra_Heater_Offset',
'4CRExtra_Heater_Nonoffset',
'5ERClosed_Cycle_Period',
'5ERPeriod',
'5ERCirculation_Period',
'5ERWaterInlet',
'5ERRPM',
'5ERTemperature',
'5ERLower_Spray_Circulation_Period',
'5ERUpper_Spray_Circulation_Period',
'5ERTop_Spray_Circulation_Period',
'5ERZone_Spray_Circulation_Period',
'5ERWaiting',
'5ERFan',
'5ERDoor_Openening',
'5ERFan_Flap',
'5ERExtra_Heater_Offset',
'5ERExtra_Heater_Nonoffset',
'6HRClosed_Cycle_Period',
'6HRPeriod',
'6HRCirculation_Period',
'6HRWaterInlet',
'6HRRPM',
'6HRTemperature',
'6HRLower_Spray_Circulation_Period',
'6HRUpper_Spray_Circulation_Period',
'6HRTop_Spray_Circulation_Period',
'6HRZone_Spray_Circulation_Period',
'6HRWaiting',
'6HRFan',
'6HRDoor_Openening',
'6HRFan_Flap',
'6HRExtra_Heater_Offset',
'6HRExtra_Heater_Nonoffset',
'7RSClosed_Cycle_Period',
'7RSPeriod',
'7RSCirculation_Period',
'7RSWaterInlet',
'7RSRPM',
'7RSTemperature',
'7RSLower_Spray_Circulation_Period',
'7RSUpper_Spray_Circulation_Period',
'7RSTop_Spray_Circulation_Period',
'7RSZone_Spray_Circulation_Period',
'7RSWaiting',
'7RSFan',
'7RSDoor_Openening',
'7RSFan_Flap',
'7RSExtra_Heater_Offset',
'7RSExtra_Heater_Nonoffset',
'8DSClosed_Cycle_Period',
'8DSPeriod',
'8DSCirculation_Period',
'8DSWaterInlet',
'8DSRPM',
'8DSTemperature',
'8DSLower_Spray_Circulation_Period',
'8DSUpper_Spray_Circulation_Period',
'8DSTop_Spray_Circulation_Period',
'8DSZone_Spray_Circulation_Period',
'8DSWaiting',
'8DSFan',
'8DSDoor_Openening',
'8DSFan_Flap',
'8DSExtra_Heater_Offset',
'8DSExtra_Heater_Nonoffset',
'9RYClosed_Cycle_Period',
'9RYPeriod',
'9RYCirculation_Period',
'9RYWaterInlet',
'9RYRPM',
'9RYTemperature',
'9RYLower_Spray_Circulation_Period',
'9RYUpper_Spray_Circulation_Period',
'9RYTop_Spray_Circulation_Period',
'9RYZone_Spray_Circulation_Period',
'9RYWaiting',
'9RYFan',
'9RYDoor_Openening',
'9RYFan_Flap',
'9RYExtra_Heater_Offset',
'9RYExtra_Heater_Nonoffset',
'10DYClosed_Cycle_Period',
'10DYPeriod',
'10DYCirculation_Period',
'10DYWaterInlet',
'10DYRPM',
'10DYTemperature',
'10DYLower_Spray_Circulation_Period',
'10DYUpper_Spray_Circulation_Period',
'10DYTop_Spray_Circulation_Period',
'10DYZone_Spray_Circulation_Period',
'10DYWaiting',
'10DYFan',
'10DYDoor_Openening',
'10DYFan_Flap',
'10DYExtra_Heater_Offset',
'10DYExtra_Heater_Nonoffset']

# %%
data=['CPI','DPI','EC','T','WC',
     '1PWClosed_Cycle_Period',
'1PWPeriod',
'1PWCirculation_Period',
'1PWWaterInlet',
'1PWRPM',
'1PWTemperature',
'1PWLower_Spray_Circulation_Period',
'1PWUpper_Spray_Circulation_Period',
'1PWTop_Spray_Circulation_Period',
'1PWZone_Spray_Circulation_Period',
'1PWWaiting',
'1PWFan',
'1PWDoor_Openening',
'1PWFan_Flap',
'1PWExtra_Heater_Offset',
'1PWExtra_Heater_Nonoffset',
'2MWClosed_Cycle_Period',
'2MWPeriod',
'2MWCirculation_Period',
'2MWWaterInlet',
'2MWRPM',
'2MWTemperature',
'2MWLower_Spray_Circulation_Period',
'2MWUpper_Spray_Circulation_Period',
'2MWTop_Spray_Circulation_Period',
'2MWZone_Spray_Circulation_Period',
'2MWWaiting',
'2MWFan',
'2MWDoor_Openening',
'2MWFan_Flap',
'2MWExtra_Heater_Offset',
'2MWExtra_Heater_Nonoffset',
'3MFClosed_Cycle_Period',
'3MFPeriod',
'3MFCirculation_Period',
'3MFWaterInlet',
'3MFRPM',
'3MFTemperature',
'3MFLower_Spray_Circulation_Period',
'3MFUpper_Spray_Circulation_Period',
'3MFTop_Spray_Circulation_Period',
'3MFZone_Spray_Circulation_Period',
'3MFWaiting',
'3MFFan',
'3MFDoor_Openening',
'3MFFan_Flap',
'3MFExtra_Heater_Offset',
'3MFExtra_Heater_Nonoffset',
'4CRClosed_Cycle_Period',
'4CRPeriod',
'4CRCirculation_Period',
'4CRWaterInlet',
'4CRRPM',
'4CRTemperature',
'4CRLower_Spray_Circulation_Period',
'4CRUpper_Spray_Circulation_Period',
'4CRTop_Spray_Circulation_Period',
'4CRZone_Spray_Circulation_Period',
'4CRWaiting',
'4CRFan',
'4CRDoor_Openening',
'4CRFan_Flap',
'4CRExtra_Heater_Offset',
'4CRExtra_Heater_Nonoffset',
'5ERClosed_Cycle_Period',
'5ERPeriod',
'5ERCirculation_Period',
'5ERWaterInlet',
'5ERRPM',
'5ERTemperature',
'5ERLower_Spray_Circulation_Period',
'5ERUpper_Spray_Circulation_Period',
'5ERTop_Spray_Circulation_Period',
'5ERZone_Spray_Circulation_Period',
'5ERWaiting',
'5ERFan',
'5ERDoor_Openening',
'5ERFan_Flap',
'5ERExtra_Heater_Offset',
'5ERExtra_Heater_Nonoffset',
'6HRClosed_Cycle_Period',
'6HRPeriod',
'6HRCirculation_Period',
'6HRWaterInlet',
'6HRRPM',
'6HRTemperature',
'6HRLower_Spray_Circulation_Period',
'6HRUpper_Spray_Circulation_Period',
'6HRTop_Spray_Circulation_Period',
'6HRZone_Spray_Circulation_Period',
'6HRWaiting',
'6HRFan',
'6HRDoor_Openening',
'6HRFan_Flap',
'6HRExtra_Heater_Offset',
'6HRExtra_Heater_Nonoffset',
'7RSClosed_Cycle_Period',
'7RSPeriod',
'7RSCirculation_Period',
'7RSWaterInlet',
'7RSRPM',
'7RSTemperature',
'7RSLower_Spray_Circulation_Period',
'7RSUpper_Spray_Circulation_Period',
'7RSTop_Spray_Circulation_Period',
'7RSZone_Spray_Circulation_Period',
'7RSWaiting',
'7RSFan',
'7RSDoor_Openening',
'7RSFan_Flap',
'7RSExtra_Heater_Offset',
'7RSExtra_Heater_Nonoffset',
'8DSClosed_Cycle_Period',
'8DSPeriod',
'8DSCirculation_Period',
'8DSWaterInlet',
'8DSRPM',
'8DSTemperature',
'8DSLower_Spray_Circulation_Period',
'8DSUpper_Spray_Circulation_Period',
'8DSTop_Spray_Circulation_Period',
'8DSZone_Spray_Circulation_Period',
'8DSWaiting',
'8DSFan',
'8DSDoor_Openening',
'8DSFan_Flap',
'8DSExtra_Heater_Offset',
'8DSExtra_Heater_Nonoffset',
'9RYClosed_Cycle_Period',
'9RYPeriod',
'9RYCirculation_Period',
'9RYWaterInlet',
'9RYRPM',
'9RYTemperature',
'9RYLower_Spray_Circulation_Period',
'9RYUpper_Spray_Circulation_Period',
'9RYTop_Spray_Circulation_Period',
'9RYZone_Spray_Circulation_Period',
'9RYWaiting',
'9RYFan',
'9RYDoor_Openening',
'9RYFan_Flap',
'9RYExtra_Heater_Offset',
'9RYExtra_Heater_Nonoffset',
'10DYClosed_Cycle_Period',
'10DYPeriod',
'10DYCirculation_Period',
'10DYWaterInlet',
'10DYRPM',
'10DYTemperature',
'10DYLower_Spray_Circulation_Period',
'10DYUpper_Spray_Circulation_Period',
'10DYTop_Spray_Circulation_Period',
'10DYZone_Spray_Circulation_Period',
'10DYWaiting',
'10DYFan',
'10DYDoor_Openening',
'10DYFan_Flap',
'10DYExtra_Heater_Offset',
'10DYExtra_Heater_Nonoffset']

# %%
df=df_ref[data]

# %%
y_CPI = df['CPI']
y_DPI = df['DPI']
y_EC=df['EC']
y_T=df['T']
y_WC=df['WC']

# %%
df_ver_0=df.drop_duplicates(keep='last',subset=indvar)

# %%
df_ver_0_X=df_ver_0[indvar]

# %%
df_ver_0_X
# Out:
#      1PWClosed_Cycle_Period  1PWPeriod  1PWCirculation_Period  1PWWaterInlet  \
# 3                         2         48                     43            4.8
# 4                         3         49                     44            4.8
# 5                         8         54                     49            4.8
# 6                         8         54                     49            4.8
# 8                         8         55                     49            7.1
# ..                      ...        ...                    ...            ...
# 149                       0         23                     20            4.6
# 150                       0         19                     16            4.0
# 151                       0          8                      6            3.5
# 152                       0         19                     16            4.0
# 153                       0         24                     21            4.0
#
#      1PWRPM  1PWTemperature  1PWLower_Spray_Circulation_Period  \
# 3      2800              53                               14.6
# 4      2800              55                               14.6
# 5      2800              56                               14.6
# 6      2800              55                               14.6
# 8      2800              55                               14.6
# ..      ...             ...                                ...
# 149    2800               0                               20.0
# 150    2800               0                                6.6
# 151    2800               0                                6.0
# 152    2800               0                                6.5
# 153    2800               0                                7.4
#
#      1PWUpper_Spray_Circulation_Period  1PWTop_Spray_Circulation_Period  \
# 3                                 18.6                              7.8
# 4                                 18.6                              7.8
# 5                                 18.6                              7.8
# 6                                 18.6                              7.8
# 8                                 18.6                              7.8
# ..                                 ...                              ...
# 149                               20.0                              0.0
# 150                                5.6                              3.8
# 151                                6.0                              0.0
# 152                                5.5                              4.0
# 153                                8.4                              5.2
#
#      1PWZone_Spray_Circulation_Period  ...  \
# 3                                   0  ...
# 4                                   0  ...
# 5                                   0  ...
# 6                                   0  ...
# 8                                   0  ...
# ..                                ...  ...
# 149                                 0  ...
# 150                                 0  ...
# 151                                 0  ...
# 152                                 0  ...
# 153                                 0  ...
#
#      10DYLower_Spray_Circulation_Period  10DYUpper_Spray_Circulation_Period  \
# 3                                     0                                   0
# 4                                     0                                   0
# 5                                     0                                   0
# 6                                     0                                   0
# 8                                     0                                   0
# ..                                  ...                                 ...
# 149                                   0                                   0
# 150                                   0                                   0
# 151                                   0                                   0
# 152                                   0                                   0
# 153                                   0                                   0
#
#      10DYTop_Spray_Circulation_Period  10DYZone_Spray_Circulation_Period  \
# 3                                   0                                  0
# 4                                   0                                  0
# 5                                   0                                  0
# 6                                   0                                  0
# 8                                   0                                  0
# ..                                ...                                ...
# 149                                 0                                  0
# 150                                 0                                  0
# 151                                 0                                  0
# 152                                 0                                  0
# 153                                 0                                  0
#
#      10DYWaiting  10DYFan  10DYDoor_Openening  10DYFan_Flap  \
# 3             50       57                   1            30
# 4             30       63                   1            29
# 5             30       80                   1            38
# 6             30       63                   1            29
# 8             30       63                   1            29
# ..           ...      ...                 ...           ...
# 149          102        0                   0             0
# 150           20       73                   0             0
# 151          123        0                   0             0
# 152           10       98                   0            37
# 153           10       98                   0            34
#
#      10DYExtra_Heater_Offset  10DYExtra_Heater_Nonoffset
# 3                          0                           0
# 4                          0                           0
# 5                          0                           0
# 6                          0                           0
# 8                          0                           0
# ..                       ...                         ...
# 149                        0                           0
# 150                        0                           0
# 151                        0                           0
# 152                        0                           0
# 153                        0                           0
#
# [94 rows x 160 columns]

# %%
y_CPI = df_ver_0['CPI']
y_DPI = df_ver_0['DPI']
y_EC=df_ver_0['EC']
y_T=df_ver_0['T']
y_WC=df_ver_0['WC']

# %%
from sklearn.feature_selection import VarianceThreshold
var_thr = VarianceThreshold(threshold = 0.05)
var_thr.fit(df_ver_0_X)
var_thr.get_support()
concol = [column for column in df_ver_0_X.columns 
          if column not in df_ver_0_X.columns[var_thr.get_support()]]
df_ver_1=df_ver_0_X.drop(concol,axis=1)
df_ver_1.columns
# Out:
# Index(['1PWClosed_Cycle_Period', '1PWPeriod', '1PWCirculation_Period',
#        '1PWWaterInlet', '1PWRPM', '1PWTemperature',
#        '1PWLower_Spray_Circulation_Period',
#        '1PWUpper_Spray_Circulation_Period', '1PWTop_Spray_Circulation_Period',
#        '1PWWaiting', '2MWClosed_Cycle_Period', '2MWPeriod',
#        '2MWCirculation_Period', '2MWWaterInlet', '2MWRPM', '2MWTemperature',
#        '2MWLower_Spray_Circulation_Period',
#        '2MWUpper_Spray_Circulation_Period', '2MWTop_Spray_Circulation_Period',
#        '3MFPeriod', '3MFWaterInlet', '4CRPeriod', '4CRCirculation_Period',
#        '4CRWaterInlet', '4CRRPM', '4CRLower_Spray_Circulation_Period',
#        '4CRUpper_Spray_Circulation_Period', '4CRTop_Spray_Circulation_Period',
#        '4CRWaiting', '7RSClosed_Cycle_Period', '7RSPeriod',
#        '7RSCirculation_Period', '7RSWaterInlet', '7RSRPM', '7RSTemperature',
#        '7RSLower_Spray_Circulation_Period',
#        '7RSUpper_Spray_Circulation_Period', '7RSTop_Spray_Circulation_Period',
#        '7RSWaiting', '8DSClosed_Cycle_Period', '8DSPeriod',
#        '8DSCirculation_Period', '8DSRPM', '10DYPeriod', '10DYWaiting',
#        '10DYFan', '10DYDoor_Openening', '10DYFan_Flap',
#        '10DYExtra_Heater_Offset'],
#       dtype='object')

# %%
# Analysis of a Matrix 
# input matrix name
matrix_name= df_ver_1
X_matrix = matrix_name.to_numpy()
rank = np.linalg.matrix_rank(X_matrix)
print("\nRank:", rank)
XMT=np.transpose(X_matrix)
XTX=np.dot(XMT,X_matrix)
det = np.linalg.det(XTX)
print("\nDeterminant:", det)
Co=np.linalg.cond(X_matrix)
print("\nCondition Number :", Co)
# Out:
# Rank: 47
#
# Determinant: 0.0
#
# Condition Number : 1.9813780192096556e+21

# %%
df_ver_2=df_ver_1

# %%
correlation_matrix=df_ver_2.corr()
correlated_features = set()

# %%
correlation_matrix
# Out:
#                                    1PWClosed_Cycle_Period  1PWPeriod  \
# 1PWClosed_Cycle_Period                           1.000000   0.426682
# 1PWPeriod                                        0.426682   1.000000
# 1PWCirculation_Period                            0.660697   0.594169
# 1PWWaterInlet                                    0.332514   0.657080
# 1PWRPM                                           0.199347   0.505981
# 1PWTemperature                                   0.670577   0.518153
# 1PWLower_Spray_Circulation_Period                0.316777   0.404520
# 1PWUpper_Spray_Circulation_Period                0.407472   0.440550
# 1PWTop_Spray_Circulation_Period                  0.579783   0.557922
# 1PWWaiting                                      -0.050854   0.694511
# 2MWClosed_Cycle_Period                           0.634542   0.321393
# 2MWPeriod                                        0.208228   0.457811
# 2MWCirculation_Period                            0.217416   0.482085
# 2MWWaterInlet                                   -0.317409  -0.685967
# 2MWRPM                                          -0.273768  -0.169221
# 2MWTemperature                                  -0.204045  -0.249916
# 2MWLower_Spray_Circulation_Period               -0.092964  -0.137890
# 2MWUpper_Spray_Circulation_Period               -0.212794  -0.272717
# 2MWTop_Spray_Circulation_Period                  0.277520   0.512033
# 3MFPeriod                                        0.462633   0.395807
# 3MFWaterInlet                                    0.339216   0.344415
# 4CRPeriod                                        0.367070   0.758560
# 4CRCirculation_Period                            0.339934   0.788600
# 4CRWaterInlet                                   -0.183207  -0.385959
# 4CRRPM                                          -0.495379  -0.538888
# 4CRLower_Spray_Circulation_Period               -0.160074   0.061157
# 4CRUpper_Spray_Circulation_Period                0.238543   0.492120
# 4CRTop_Spray_Circulation_Period                  0.340509   0.719563
# 4CRWaiting                                       0.466500   0.377043
# 7RSClosed_Cycle_Period                           0.404487   0.314488
# 7RSPeriod                                        0.268921   0.425111
# 7RSCirculation_Period                            0.225136   0.393684
# 7RSWaterInlet                                   -0.568350  -0.503716
# 7RSRPM                                          -0.441854  -0.333103
# 7RSTemperature                                  -0.193356  -0.378404
# 7RSLower_Spray_Circulation_Period               -0.348531  -0.180357
# 7RSUpper_Spray_Circulation_Period               -0.043266  -0.186055
# 7RSTop_Spray_Circulation_Period                  0.261340   0.305737
# 7RSWaiting                                       0.532965   0.420650
# 8DSClosed_Cycle_Period                          -0.088190   0.101720
# 8DSPeriod                                       -0.088190   0.101720
# 8DSCirculation_Period                           -0.088190   0.101720
# 8DSRPM                                           0.174346   0.175563
# 10DYPeriod                                       0.137063   0.287814
# 10DYWaiting                                      0.057745  -0.205461
# 10DYFan                                          0.051646   0.441719
# 10DYDoor_Openening                               0.494272   0.252495
# 10DYFan_Flap                                     0.269730   0.483781
# 10DYExtra_Heater_Offset                         -0.038582  -0.014352
#
#                                    1PWCirculation_Period  1PWWaterInlet  \
# 1PWClosed_Cycle_Period                          0.660697       0.332514
# 1PWPeriod                                       0.594169       0.657080
# 1PWCirculation_Period                           1.000000       0.722748
# 1PWWaterInlet                                   0.722748       1.000000
# 1PWRPM                                          0.584552       0.852077
# 1PWTemperature                                  0.848592       0.464756
# 1PWLower_Spray_Circulation_Period               0.771085       0.767590
# 1PWUpper_Spray_Circulation_Period               0.837292       0.754345
# 1PWTop_Spray_Circulation_Period                 0.865596       0.537052
# 1PWWaiting                                     -0.164665       0.131326
# 2MWClosed_Cycle_Period                          0.499906       0.323171
# 2MWPeriod                                       0.441921       0.461172
# 2MWCirculation_Period                           0.463516       0.486117
# 2MWWaterInlet                                  -0.645719      -0.674835
# 2MWRPM                                         -0.320842      -0.141453
# 2MWTemperature                                 -0.299259      -0.103263
# 2MWLower_Spray_Circulation_Period              -0.110698      -0.040026
# 2MWUpper_Spray_Circulation_Period              -0.271049      -0.138876
# 2MWTop_Spray_Circulation_Period                 0.584402       0.510281
# 3MFPeriod                                       0.635237       0.325891
# 3MFWaterInlet                                   0.557172       0.253939
# 4CRPeriod                                       0.621849       0.469432
# 4CRCirculation_Period                           0.607656       0.510613
# 4CRWaterInlet                                  -0.419093      -0.599687
# 4CRRPM                                         -0.697664      -0.522320
# 4CRLower_Spray_Circulation_Period              -0.101496       0.018428
# 4CRUpper_Spray_Circulation_Period               0.414281       0.385027
# 4CRTop_Spray_Circulation_Period                 0.626701       0.461818
# 4CRWaiting                                      0.606193       0.314900
# 7RSClosed_Cycle_Period                          0.519353       0.264039
# 7RSPeriod                                       0.618433       0.590571
# 7RSCirculation_Period                           0.563273       0.562556
# 7RSWaterInlet                                  -0.767063      -0.489633
# 7RSRPM                                         -0.673054      -0.425823
# 7RSTemperature                                 -0.203733      -0.242774
# 7RSLower_Spray_Circulation_Period              -0.246553       0.097195
# 7RSUpper_Spray_Circulation_Period              -0.012943       0.143535
# 7RSTop_Spray_Circulation_Period                 0.589584       0.452134
# 7RSWaiting                                      0.671087       0.371196
# 8DSClosed_Cycle_Period                          0.172761       0.100216
# 8DSPeriod                                       0.172761       0.100216
# 8DSCirculation_Period                           0.172761       0.100216
# 8DSRPM                                          0.315107       0.137182
# 10DYPeriod                                      0.288149       0.412463
# 10DYWaiting                                    -0.040517      -0.146513
# 10DYFan                                         0.274777       0.490459
# 10DYDoor_Openening                              0.544438       0.215414
# 10DYFan_Flap                                    0.354838       0.405474
# 10DYExtra_Heater_Offset                         0.009368       0.043843
#
#                                      1PWRPM  1PWTemperature  \
# 1PWClosed_Cycle_Period             0.199347        0.670577
# 1PWPeriod                          0.505981        0.518153
# 1PWCirculation_Period              0.584552        0.848592
# 1PWWaterInlet                      0.852077        0.464756
# 1PWRPM                             1.000000        0.312787
# 1PWTemperature                     0.312787        1.000000
# 1PWLower_Spray_Circulation_Period  0.621917        0.677614
# 1PWUpper_Spray_Circulation_Period  0.595799        0.746970
# 1PWTop_Spray_Circulation_Period    0.467361        0.656416
# 1PWWaiting                         0.067587       -0.107581
# 2MWClosed_Cycle_Period             0.120136        0.411298
# 2MWPeriod                          0.593120        0.173862
# 2MWCirculation_Period              0.611247        0.182174
# 2MWWaterInlet                     -0.633941       -0.258759
# 2MWRPM                            -0.069976       -0.361097
# 2MWTemperature                    -0.097080       -0.245067
# 2MWLower_Spray_Circulation_Period  0.114344       -0.099518
# 2MWUpper_Spray_Circulation_Period  0.057474       -0.244593
# 2MWTop_Spray_Circulation_Period    0.515606        0.269528
# 3MFPeriod                          0.190258        0.623868
# 3MFWaterInlet                      0.173480        0.565088
# 4CRPeriod                          0.444862        0.545507
# 4CRCirculation_Period              0.488979        0.495971
# 4CRWaterInlet                     -0.590265       -0.090268
# 4CRRPM                            -0.359615       -0.516202
# 4CRLower_Spray_Circulation_Period  0.047399        0.043576
# 4CRUpper_Spray_Circulation_Period  0.433112        0.401799
# 4CRTop_Spray_Circulation_Period    0.402932        0.484735
# 4CRWaiting                         0.184859        0.606163
# 7RSClosed_Cycle_Period             0.276773        0.452900
# 7RSPeriod                          0.587724        0.270838
# 7RSCirculation_Period              0.579240        0.210496
# 7RSWaterInlet                     -0.348008       -0.636749
# 7RSRPM                            -0.296342       -0.562690
# 7RSTemperature                    -0.230651       -0.008177
# 7RSLower_Spray_Circulation_Period  0.105776       -0.345458
# 7RSUpper_Spray_Circulation_Period  0.137552       -0.051955
# 7RSTop_Spray_Circulation_Period    0.482112        0.262323
# 7RSWaiting                         0.195046        0.641889
# 8DSClosed_Cycle_Period             0.143176        0.086031
# 8DSPeriod                          0.143176        0.086031
# 8DSCirculation_Period              0.143176        0.086031
# 8DSRPM                             0.187089        0.310886
# 10DYPeriod                         0.584766       -0.006263
# 10DYWaiting                        0.033600        0.079356
# 10DYFan                            0.463819       -0.093864
# 10DYDoor_Openening                 0.100929        0.552336
# 10DYFan_Flap                       0.315437        0.167074
# 10DYExtra_Heater_Offset            0.073260       -0.060538
#
#                                    1PWLower_Spray_Circulation_Period  \
# 1PWClosed_Cycle_Period                                      0.316777
# 1PWPeriod                                                   0.404520
# 1PWCirculation_Period                                       0.771085
# 1PWWaterInlet                                               0.767590
# 1PWRPM                                                      0.621917
# 1PWTemperature                                              0.677614
# 1PWLower_Spray_Circulation_Period                           1.000000
# 1PWUpper_Spray_Circulation_Period                           0.981499
# 1PWTop_Spray_Circulation_Period                             0.411739
# 1PWWaiting                                                 -0.206621
# 2MWClosed_Cycle_Period                                      0.264683
# 2MWPeriod                                                   0.246237
# 2MWCirculation_Period                                       0.261851
# 2MWWaterInlet                                              -0.385157
# 2MWRPM                                                     -0.355201
# 2MWTemperature                                             -0.062101
# 2MWLower_Spray_Circulation_Period                           0.120577
# 2MWUpper_Spray_Circulation_Period                           0.028133
# 2MWTop_Spray_Circulation_Period                             0.185473
# 3MFPeriod                                                   0.362944
# 3MFWaterInlet                                               0.322697
# 4CRPeriod                                                   0.315624
# 4CRCirculation_Period                                       0.313249
# 4CRWaterInlet                                              -0.313780
# 4CRRPM                                                     -0.430013
# 4CRLower_Spray_Circulation_Period                           0.257667
# 4CRUpper_Spray_Circulation_Period                           0.423081
# 4CRTop_Spray_Circulation_Period                             0.220095
# 4CRWaiting                                                  0.341861
# 7RSClosed_Cycle_Period                                      0.254462
# 7RSPeriod                                                   0.407253
# 7RSCirculation_Period                                       0.370787
# 7RSWaterInlet                                              -0.398892
# 7RSRPM                                                     -0.564198
# 7RSTemperature                                              0.080476
# 7RSLower_Spray_Circulation_Period                           0.234283
# 7RSUpper_Spray_Circulation_Period                           0.402693
# 7RSTop_Spray_Circulation_Period                             0.219408
# 7RSWaiting                                                  0.380766
# 8DSClosed_Cycle_Period                                      0.108687
# 8DSPeriod                                                   0.108687
# 8DSCirculation_Period                                       0.108687
# 8DSRPM                                                      0.190586
# 10DYPeriod                                                  0.206568
# 10DYWaiting                                                 0.094712
# 10DYFan                                                     0.078497
# 10DYDoor_Openening                                          0.210329
# 10DYFan_Flap                                                0.103320
# 10DYExtra_Heater_Offset                                    -0.012878
#
#                                    1PWUpper_Spray_Circulation_Period  \
# 1PWClosed_Cycle_Period                                      0.407472
# 1PWPeriod                                                   0.440550
# 1PWCirculation_Period                                       0.837292
# 1PWWaterInlet                                               0.754345
# 1PWRPM                                                      0.595799
# 1PWTemperature                                              0.746970
# 1PWLower_Spray_Circulation_Period                           0.981499
# 1PWUpper_Spray_Circulation_Period                           1.000000
# 1PWTop_Spray_Circulation_Period                             0.489669
# 1PWWaiting                                                 -0.216380
# 2MWClosed_Cycle_Period                                      0.350221
# 2MWPeriod                                                   0.258202
# 2MWCirculation_Period                                       0.273520
# 2MWWaterInlet                                              -0.398519
# 2MWRPM                                                     -0.406544
# 2MWTemperature                                             -0.100715
# 2MWLower_Spray_Circulation_Period                           0.106831
# 2MWUpper_Spray_Circulation_Period                          -0.015322
# 2MWTop_Spray_Circulation_Period                             0.205940
# 3MFPeriod                                                   0.467137
# 3MFWaterInlet                                               0.415361
# 4CRPeriod                                                   0.358790
# 4CRCirculation_Period                                       0.341924
# 4CRWaterInlet                                              -0.311212
# 4CRRPM                                                     -0.492411
# 4CRLower_Spray_Circulation_Period                           0.219837
# 4CRUpper_Spray_Circulation_Period                           0.412287
# 4CRTop_Spray_Circulation_Period                             0.262892
# 4CRWaiting                                                  0.442615
# 7RSClosed_Cycle_Period                                      0.293851
# 7RSPeriod                                                   0.411309
# 7RSCirculation_Period                                       0.365833
# 7RSWaterInlet                                              -0.504096
# 7RSRPM                                                     -0.588608
# 7RSTemperature                                              0.045731
# 7RSLower_Spray_Circulation_Period                           0.147834
# 7RSUpper_Spray_Circulation_Period                           0.340064
# 7RSTop_Spray_Circulation_Period                             0.256071
# 7RSWaiting                                                  0.490650
# 8DSClosed_Cycle_Period                                      0.090770
# 8DSPeriod                                                   0.090770
# 8DSCirculation_Period                                       0.090770
# 8DSRPM                                                      0.169206
# 10DYPeriod                                                  0.204003
# 10DYWaiting                                                 0.105816
# 10DYFan                                                     0.063669
# 10DYDoor_Openening                                          0.299769
# 10DYFan_Flap                                                0.127598
# 10DYExtra_Heater_Offset                                    -0.017712
#
#                                    1PWTop_Spray_Circulation_Period  \
# 1PWClosed_Cycle_Period                                    0.579783
# 1PWPeriod                                                 0.557922
# 1PWCirculation_Period                                     0.865596
# 1PWWaterInlet                                             0.537052
# 1PWRPM                                                    0.467361
# 1PWTemperature                                            0.656416
# 1PWLower_Spray_Circulation_Period                         0.411739
# 1PWUpper_Spray_Circulation_Period                         0.489669
# 1PWTop_Spray_Circulation_Period                           1.000000
# 1PWWaiting                                               -0.085722
# 2MWClosed_Cycle_Period                                    0.416330
# 2MWPeriod                                                 0.510745
# 2MWCirculation_Period                                     0.533032
# 2MWWaterInlet                                            -0.715447
# 2MWRPM                                                   -0.137815
# 2MWTemperature                                           -0.363298
# 2MWLower_Spray_Circulation_Period                        -0.271381
# 2MWUpper_Spray_Circulation_Period                        -0.412321
# 2MWTop_Spray_Circulation_Period                           0.817273
# 3MFPeriod                                                 0.569495
# 3MFWaterInlet                                             0.507055
# 4CRPeriod                                                 0.681451
# 4CRCirculation_Period                                     0.682024
# 4CRWaterInlet                                            -0.426905
# 4CRRPM                                                   -0.668393
# 4CRLower_Spray_Circulation_Period                        -0.364361
# 4CRUpper_Spray_Circulation_Period                         0.315491
# 4CRTop_Spray_Circulation_Period                           0.804820
# 4CRWaiting                                                0.539063
# 7RSClosed_Cycle_Period                                    0.565527
# 7RSPeriod                                                 0.678802
# 7RSCirculation_Period                                     0.634415
# 7RSWaterInlet                                            -0.751810
# 7RSRPM                                                   -0.556564
# 7RSTemperature                                           -0.358960
# 7RSLower_Spray_Circulation_Period                        -0.476433
# 7RSUpper_Spray_Circulation_Period                        -0.300708
# 7RSTop_Spray_Circulation_Period                           0.774863
# 7RSWaiting                                                0.596762
# 8DSClosed_Cycle_Period                                    0.221789
# 8DSPeriod                                                 0.221789
# 8DSCirculation_Period                                     0.221789
# 8DSRPM                                                    0.303050
# 10DYPeriod                                                0.303527
# 10DYWaiting                                              -0.184345
# 10DYFan                                                   0.429002
# 10DYDoor_Openening                                        0.561901
# 10DYFan_Flap                                              0.444820
# 10DYExtra_Heater_Offset                                   0.041703
#
#                                    1PWWaiting  ...  8DSClosed_Cycle_Period  \
# 1PWClosed_Cycle_Period              -0.050854  ...               -0.088190
# 1PWPeriod                            0.694511  ...                0.101720
# 1PWCirculation_Period               -0.164665  ...                0.172761
# 1PWWaterInlet                        0.131326  ...                0.100216
# 1PWRPM                               0.067587  ...                0.143176
# 1PWTemperature                      -0.107581  ...                0.086031
# 1PWLower_Spray_Circulation_Period   -0.206621  ...                0.108687
# 1PWUpper_Spray_Circulation_Period   -0.216380  ...                0.090770
# 1PWTop_Spray_Circulation_Period     -0.085722  ...                0.221789
# 1PWWaiting                           1.000000  ...               -0.043366
# 2MWClosed_Cycle_Period              -0.041026  ...               -0.053148
# 2MWPeriod                            0.156978  ...                0.124729
# 2MWCirculation_Period                0.166716  ...                0.132818
# 2MWWaterInlet                       -0.249533  ...               -0.202199
# 2MWRPM                               0.066460  ...                0.025490
# 2MWTemperature                      -0.049148  ...               -0.016786
# 2MWLower_Spray_Circulation_Period   -0.070278  ...               -0.087083
# 2MWUpper_Spray_Circulation_Period   -0.095786  ...               -0.112800
# 2MWTop_Spray_Circulation_Period      0.094654  ...                0.218333
# 3MFPeriod                           -0.064972  ...               -0.084169
# 3MFWaterInlet                       -0.059243  ...               -0.076747
# 4CRPeriod                            0.378358  ...                0.189327
# 4CRCirculation_Period                0.423416  ...                0.224182
# 4CRWaterInlet                       -0.075504  ...               -0.107048
# 4CRRPM                              -0.041620  ...               -0.119991
# 4CRLower_Spray_Circulation_Period    0.166555  ...               -0.035428
# 4CRUpper_Spray_Circulation_Period    0.230665  ...                0.099726
# 4CRTop_Spray_Circulation_Period      0.324494  ...                0.228045
# 4CRWaiting                          -0.063128  ...               -0.081781
# 7RSClosed_Cycle_Period              -0.080546  ...                0.605302
# 7RSPeriod                           -0.049034  ...                0.250670
# 7RSCirculation_Period               -0.040048  ...                0.261045
# 7RSWaterInlet                        0.056670  ...                0.037167
# 7RSRPM                               0.189548  ...               -0.089048
# 7RSTemperature                      -0.279702  ...                0.112875
# 7RSLower_Spray_Circulation_Period   -0.019969  ...               -0.097884
# 7RSUpper_Spray_Circulation_Period   -0.228599  ...               -0.102619
# 7RSTop_Spray_Circulation_Period     -0.162377  ...                0.131986
# 7RSWaiting                          -0.066607  ...               -0.086287
# 8DSClosed_Cycle_Period              -0.043366  ...                1.000000
# 8DSPeriod                           -0.043366  ...                1.000000
# 8DSCirculation_Period               -0.043366  ...                1.000000
# 8DSRPM                              -0.073944  ...                0.775733
# 10DYPeriod                           0.080858  ...                0.056924
# 10DYWaiting                         -0.208841  ...               -0.054833
# 10DYFan                              0.276671  ...                0.103214
# 10DYDoor_Openening                  -0.164409  ...                0.018892
# 10DYFan_Flap                         0.270279  ...                0.169553
# 10DYExtra_Heater_Offset             -0.030332  ...               -0.024578
#
#                                    8DSPeriod  8DSCirculation_Period    8DSRPM  \
# 1PWClosed_Cycle_Period             -0.088190              -0.088190  0.174346
# 1PWPeriod                           0.101720               0.101720  0.175563
# 1PWCirculation_Period               0.172761               0.172761  0.315107
# 1PWWaterInlet                       0.100216               0.100216  0.137182
# 1PWRPM                              0.143176               0.143176  0.187089
# 1PWTemperature                      0.086031               0.086031  0.310886
# 1PWLower_Spray_Circulation_Period   0.108687               0.108687  0.190586
# 1PWUpper_Spray_Circulation_Period   0.090770               0.090770  0.169206
# 1PWTop_Spray_Circulation_Period     0.221789               0.221789  0.303050
# 1PWWaiting                         -0.043366              -0.043366 -0.073944
# 2MWClosed_Cycle_Period             -0.053148              -0.053148 -0.072752
# 2MWPeriod                           0.124729               0.124729  0.167790
# 2MWCirculation_Period               0.132818               0.132818  0.178994
# 2MWWaterInlet                      -0.202199              -0.202199 -0.276785
# 2MWRPM                              0.025490               0.025490  0.085568
# 2MWTemperature                     -0.016786              -0.016786 -0.033020
# 2MWLower_Spray_Circulation_Period  -0.087083              -0.087083 -0.135055
# 2MWUpper_Spray_Circulation_Period  -0.112800              -0.112800 -0.133084
# 2MWTop_Spray_Circulation_Period     0.218333               0.218333  0.277990
# 3MFPeriod                          -0.084169              -0.084169 -0.115217
# 3MFWaterInlet                      -0.076747              -0.076747 -0.105056
# 4CRPeriod                           0.189327               0.189327  0.272921
# 4CRCirculation_Period               0.224182               0.224182  0.321370
# 4CRWaterInlet                      -0.107048              -0.107048 -0.166647
# 4CRRPM                             -0.119991              -0.119991 -0.161683
# 4CRLower_Spray_Circulation_Period  -0.035428              -0.035428 -0.074599
# 4CRUpper_Spray_Circulation_Period   0.099726               0.099726  0.216403
# 4CRTop_Spray_Circulation_Period     0.228045               0.228045  0.285967
# 4CRWaiting                         -0.081781              -0.081781 -0.111947
# 7RSClosed_Cycle_Period              0.605302               0.605302  0.737184
# 7RSPeriod                           0.250670               0.250670  0.363716
# 7RSCirculation_Period               0.261045               0.261045  0.377932
# 7RSWaterInlet                       0.037167               0.037167  0.026197
# 7RSRPM                             -0.089048              -0.089048 -0.227708
# 7RSTemperature                      0.112875               0.112875  0.061135
# 7RSLower_Spray_Circulation_Period  -0.097884              -0.097884 -0.160199
# 7RSUpper_Spray_Circulation_Period  -0.102619              -0.102619 -0.013288
# 7RSTop_Spray_Circulation_Period     0.131986               0.131986  0.212778
# 7RSWaiting                         -0.086287              -0.086287 -0.118116
# 8DSClosed_Cycle_Period              1.000000               1.000000  0.775733
# 8DSPeriod                           1.000000               1.000000  0.775733
# 8DSCirculation_Period               1.000000               1.000000  0.775733
# 8DSRPM                              0.775733               0.775733  1.000000
# 10DYPeriod                          0.056924               0.056924  0.030767
# 10DYWaiting                        -0.054833              -0.054833  0.063371
# 10DYFan                             0.103214               0.103214 -0.036771
# 10DYDoor_Openening                  0.018892               0.018892  0.194385
# 10DYFan_Flap                        0.169553               0.169553  0.052061
# 10DYExtra_Heater_Offset            -0.024578              -0.024578 -0.033644
#
#                                    10DYPeriod  10DYWaiting   10DYFan  \
# 1PWClosed_Cycle_Period               0.137063     0.057745  0.051646
# 1PWPeriod                            0.287814    -0.205461  0.441719
# 1PWCirculation_Period                0.288149    -0.040517  0.274777
# 1PWWaterInlet                        0.412463    -0.146513  0.490459
# 1PWRPM                               0.584766     0.033600  0.463819
# 1PWTemperature                      -0.006263     0.079356 -0.093864
# 1PWLower_Spray_Circulation_Period    0.206568     0.094712  0.078497
# 1PWUpper_Spray_Circulation_Period    0.204003     0.105816  0.063669
# 1PWTop_Spray_Circulation_Period      0.303527    -0.184345  0.429002
# 1PWWaiting                           0.080858    -0.208841  0.276671
# 2MWClosed_Cycle_Period               0.154139    -0.066659  0.189718
# 2MWPeriod                            0.862952     0.228102  0.508927
# 2MWCirculation_Period                0.859800     0.199831  0.533857
# 2MWWaterInlet                       -0.495682     0.322483 -0.734344
# 2MWRPM                              -0.183935    -0.447666  0.285179
# 2MWTemperature                      -0.313661    -0.020804 -0.242892
# 2MWLower_Spray_Circulation_Period    0.582441     0.752407 -0.237578
# 2MWUpper_Spray_Circulation_Period    0.512280     0.746470 -0.289987
# 2MWTop_Spray_Circulation_Period      0.344669    -0.435501  0.714363
# 3MFPeriod                            0.176763    -0.069729  0.207533
# 3MFWaterInlet                        0.155406    -0.061136  0.181886
# 4CRPeriod                            0.320443    -0.164365  0.426465
# 4CRCirculation_Period                0.329059    -0.200935  0.470665
# 4CRWaterInlet                       -0.498802    -0.021421 -0.403908
# 4CRRPM                              -0.296629     0.084550 -0.328467
# 4CRLower_Spray_Circulation_Period    0.139300     0.394876 -0.266813
# 4CRUpper_Spray_Circulation_Period    0.347188     0.184383  0.111758
# 4CRTop_Spray_Circulation_Period      0.230785    -0.343454  0.525401
# 4CRWaiting                           0.158913    -0.069831  0.192670
# 7RSClosed_Cycle_Period               0.136528    -0.006924  0.119666
# 7RSPeriod                            0.321756    -0.330939  0.593299
# 7RSCirculation_Period                0.321914    -0.318523  0.582251
# 7RSWaterInlet                       -0.320418     0.132837 -0.391421
# 7RSRPM                              -0.096111     0.082605 -0.159826
# 7RSTemperature                      -0.388505     0.129761 -0.454532
# 7RSLower_Spray_Circulation_Period    0.014073     0.142493 -0.121430
# 7RSUpper_Spray_Circulation_Period    0.036505     0.319179 -0.278642
# 7RSTop_Spray_Circulation_Period      0.312227    -0.369988  0.620946
# 7RSWaiting                           0.189007    -0.074159  0.222068
# 8DSClosed_Cycle_Period               0.056924    -0.054833  0.103214
# 8DSPeriod                            0.056924    -0.054833  0.103214
# 8DSCirculation_Period                0.056924    -0.054833  0.103214
# 8DSRPM                               0.030767     0.063371 -0.036771
# 10DYPeriod                           1.000000     0.410492  0.451943
# 10DYWaiting                          0.410492     1.000000 -0.627669
# 10DYFan                              0.451943    -0.627669  1.000000
# 10DYDoor_Openening                   0.071356     0.094734 -0.046079
# 10DYFan_Flap                         0.386412    -0.408755  0.727157
# 10DYExtra_Heater_Offset             -0.002523    -0.100038  0.082423
#
#                                    10DYDoor_Openening  10DYFan_Flap  \
# 1PWClosed_Cycle_Period                       0.494272      0.269730
# 1PWPeriod                                    0.252495      0.483781
# 1PWCirculation_Period                        0.544438      0.354838
# 1PWWaterInlet                                0.215414      0.405474
# 1PWRPM                                       0.100929      0.315437
# 1PWTemperature                               0.552336      0.167074
# 1PWLower_Spray_Circulation_Period            0.210329      0.103320
# 1PWUpper_Spray_Circulation_Period            0.299769      0.127598
# 1PWTop_Spray_Circulation_Period              0.561901      0.444820
# 1PWWaiting                                  -0.164409      0.270279
# 2MWClosed_Cycle_Period                       0.297873      0.393574
# 2MWPeriod                                    0.309843      0.349109
# 2MWCirculation_Period                        0.309179      0.366395
# 2MWWaterInlet                               -0.233795     -0.527769
# 2MWRPM                                      -0.250467      0.005320
# 2MWTemperature                              -0.207590     -0.332470
# 2MWLower_Spray_Circulation_Period           -0.000290     -0.179161
# 2MWUpper_Spray_Circulation_Period           -0.091363     -0.301252
# 2MWTop_Spray_Circulation_Period              0.322596      0.475516
# 3MFPeriod                                    0.471737      0.440307
# 3MFWaterInlet                                0.430136      0.388018
# 4CRPeriod                                    0.443405      0.419918
# 4CRCirculation_Period                        0.407021      0.417579
# 4CRWaterInlet                               -0.028557     -0.274483
# 4CRRPM                                      -0.378521     -0.419484
# 4CRLower_Spray_Circulation_Period            0.014672     -0.212233
# 4CRUpper_Spray_Circulation_Period            0.320850      0.073933
# 4CRTop_Spray_Circulation_Period              0.398222      0.496346
# 4CRWaiting                                   0.458349      0.414626
# 7RSClosed_Cycle_Period                       0.281881      0.277066
# 7RSPeriod                                    0.225937      0.294742
# 7RSCirculation_Period                        0.190510      0.259260
# 7RSWaterInlet                               -0.516177     -0.546127
# 7RSRPM                                      -0.219902     -0.253131
# 7RSTemperature                              -0.451445     -0.328399
# 7RSLower_Spray_Circulation_Period           -0.347575     -0.367520
# 7RSUpper_Spray_Circulation_Period           -0.162230     -0.342126
# 7RSTop_Spray_Circulation_Period              0.332347      0.335388
# 7RSWaiting                                   0.483608      0.469208
# 8DSClosed_Cycle_Period                       0.018892      0.169553
# 8DSPeriod                                    0.018892      0.169553
# 8DSCirculation_Period                        0.018892      0.169553
# 8DSRPM                                       0.194385      0.052061
# 10DYPeriod                                   0.071356      0.386412
# 10DYWaiting                                  0.094734     -0.408755
# 10DYFan                                     -0.046079      0.727157
# 10DYDoor_Openening                           1.000000     -0.001146
# 10DYFan_Flap                                -0.001146      1.000000
# 10DYExtra_Heater_Offset                     -0.078059      0.072737
#
#                                    10DYExtra_Heater_Offset
# 1PWClosed_Cycle_Period                           -0.038582
# 1PWPeriod                                        -0.014352
# 1PWCirculation_Period                             0.009368
# 1PWWaterInlet                                     0.043843
# 1PWRPM                                            0.073260
# 1PWTemperature                                   -0.060538
# 1PWLower_Spray_Circulation_Period                -0.012878
# 1PWUpper_Spray_Circulation_Period                -0.017712
# 1PWTop_Spray_Circulation_Period                   0.041703
# 1PWWaiting                                       -0.030332
# 2MWClosed_Cycle_Period                           -0.023252
# 2MWPeriod                                         0.076000
# 2MWCirculation_Period                             0.078586
# 2MWWaterInlet                                    -0.088460
# 2MWRPM                                            0.152263
# 2MWTemperature                                    0.013518
# 2MWLower_Spray_Circulation_Period                -0.068718
# 2MWUpper_Spray_Circulation_Period                -0.015422
# 2MWTop_Spray_Circulation_Period                   0.137191
# 3MFPeriod                                        -0.036823
# 3MFWaterInlet                                    -0.033576
# 4CRPeriod                                         0.018527
# 4CRCirculation_Period                             0.030330
# 4CRWaterInlet                                    -0.062026
# 4CRRPM                                           -0.004470
# 4CRLower_Spray_Circulation_Period                -0.072915
# 4CRUpper_Spray_Circulation_Period                -0.007877
# 4CRTop_Spray_Circulation_Period                   0.042145
# 4CRWaiting                                       -0.035778
# 7RSClosed_Cycle_Period                           -0.050281
# 7RSPeriod                                         0.161744
# 7RSCirculation_Period                             0.166317
# 7RSWaterInlet                                    -0.002966
# 7RSRPM                                            0.087319
# 7RSTemperature                                   -0.022902
# 7RSLower_Spray_Circulation_Period                 0.000792
# 7RSUpper_Spray_Circulation_Period                -0.014164
# 7RSTop_Spray_Circulation_Period                   0.229806
# 7RSWaiting                                       -0.037750
# 8DSClosed_Cycle_Period                           -0.024578
# 8DSPeriod                                        -0.024578
# 8DSCirculation_Period                            -0.024578
# 8DSRPM                                           -0.033644
# 10DYPeriod                                       -0.002523
# 10DYWaiting                                      -0.100038
# 10DYFan                                           0.082423
# 10DYDoor_Openening                               -0.078059
# 10DYFan_Flap                                      0.072737
# 10DYExtra_Heater_Offset                           1.000000
#
# [49 rows x 49 columns]

# %%
threshold = 0.90
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)

# %%
df_ver_3 = df_ver_2.drop(labels=correlated_features, axis=1)
df_ver_3
# Out:
#      1PWClosed_Cycle_Period  1PWPeriod  1PWCirculation_Period  1PWWaterInlet  \
# 3                         2         48                     43            4.8
# 4                         3         49                     44            4.8
# 5                         8         54                     49            4.8
# 6                         8         54                     49            4.8
# 8                         8         55                     49            7.1
# ..                      ...        ...                    ...            ...
# 149                       0         23                     20            4.6
# 150                       0         19                     16            4.0
# 151                       0          8                      6            3.5
# 152                       0         19                     16            4.0
# 153                       0         24                     21            4.0
#
#      1PWRPM  1PWTemperature  1PWLower_Spray_Circulation_Period  \
# 3      2800              53                               14.6
# 4      2800              55                               14.6
# 5      2800              56                               14.6
# 6      2800              55                               14.6
# 8      2800              55                               14.6
# ..      ...             ...                                ...
# 149    2800               0                               20.0
# 150    2800               0                                6.6
# 151    2800               0                                6.0
# 152    2800               0                                6.5
# 153    2800               0                                7.4
#
#      1PWTop_Spray_Circulation_Period  1PWWaiting  2MWClosed_Cycle_Period  ...  \
# 3                                7.8           2                       0  ...
# 4                                7.8           2                       3  ...
# 5                                7.8           2                       3  ...
# 6                                7.8           2                       3  ...
# 8                                7.8           2                       3  ...
# ..                               ...         ...                     ...  ...
# 149                              0.0           0                       0  ...
# 150                              3.8           0                       0  ...
# 151                              0.0           0                       0  ...
# 152                              4.0           0                       0  ...
# 153                              5.2           0                       0  ...
#
#      7RSLower_Spray_Circulation_Period  7RSUpper_Spray_Circulation_Period  \
# 3                                  4.5                                5.5
# 4                                  3.5                                5.5
# 5                                  4.5                                6.5
# 6                                  3.5                                5.5
# 8                                  3.5                                5.5
# ..                                 ...                                ...
# 149                               24.0                               24.0
# 150                               12.0                                8.0
# 151                               11.0                               11.0
# 152                                8.0                                7.0
# 153                                6.0                                7.0
#
#      8DSClosed_Cycle_Period  8DSRPM  10DYPeriod  10DYWaiting  10DYFan  \
# 3                         0       0         110           50       57
# 4                         0       0          96           30       63
# 5                         0       0         113           30       80
# 6                         0       0          96           30       63
# 8                         0       0          96           30       63
# ..                      ...     ...         ...          ...      ...
# 149                       0       0         103          102        0
# 150                       0       0          94           20       73
# 151                       0       0         124          123        0
# 152                       0       0         109           10       98
# 153                       0       0         109           10       98
#
#      10DYDoor_Openening  10DYFan_Flap  10DYExtra_Heater_Offset
# 3                     1            30                        0
# 4                     1            29                        0
# 5                     1            38                        0
# 6                     1            29                        0
# 8                     1            29                        0
# ..                  ...           ...                      ...
# 149                   0             0                        0
# 150                   0             0                        0
# 151                   0             0                        0
# 152                   0            37                        0
# 153                   0            34                        0
#
# [94 rows x 37 columns]

# %%
df_ver_3
# Out:
#      1PWClosed_Cycle_Period  1PWPeriod  1PWCirculation_Period  1PWWaterInlet  \
# 3                         2         48                     43            4.8
# 4                         3         49                     44            4.8
# 5                         8         54                     49            4.8
# 6                         8         54                     49            4.8
# 8                         8         55                     49            7.1
# ..                      ...        ...                    ...            ...
# 149                       0         23                     20            4.6
# 150                       0         19                     16            4.0
# 151                       0          8                      6            3.5
# 152                       0         19                     16            4.0
# 153                       0         24                     21            4.0
#
#      1PWRPM  1PWTemperature  1PWLower_Spray_Circulation_Period  \
# 3      2800              53                               14.6
# 4      2800              55                               14.6
# 5      2800              56                               14.6
# 6      2800              55                               14.6
# 8      2800              55                               14.6
# ..      ...             ...                                ...
# 149    2800               0                               20.0
# 150    2800               0                                6.6
# 151    2800               0                                6.0
# 152    2800               0                                6.5
# 153    2800               0                                7.4
#
#      1PWTop_Spray_Circulation_Period  1PWWaiting  2MWClosed_Cycle_Period  ...  \
# 3                                7.8           2                       0  ...
# 4                                7.8           2                       3  ...
# 5                                7.8           2                       3  ...
# 6                                7.8           2                       3  ...
# 8                                7.8           2                       3  ...
# ..                               ...         ...                     ...  ...
# 149                              0.0           0                       0  ...
# 150                              3.8           0                       0  ...
# 151                              0.0           0                       0  ...
# 152                              4.0           0                       0  ...
# 153                              5.2           0                       0  ...
#
#      7RSLower_Spray_Circulation_Period  7RSUpper_Spray_Circulation_Period  \
# 3                                  4.5                                5.5
# 4                                  3.5                                5.5
# 5                                  4.5                                6.5
# 6                                  3.5                                5.5
# 8                                  3.5                                5.5
# ..                                 ...                                ...
# 149                               24.0                               24.0
# 150                               12.0                                8.0
# 151                               11.0                               11.0
# 152                                8.0                                7.0
# 153                                6.0                                7.0
#
#      8DSClosed_Cycle_Period  8DSRPM  10DYPeriod  10DYWaiting  10DYFan  \
# 3                         0       0         110           50       57
# 4                         0       0          96           30       63
# 5                         0       0         113           30       80
# 6                         0       0          96           30       63
# 8                         0       0          96           30       63
# ..                      ...     ...         ...          ...      ...
# 149                       0       0         103          102        0
# 150                       0       0          94           20       73
# 151                       0       0         124          123        0
# 152                       0       0         109           10       98
# 153                       0       0         109           10       98
#
#      10DYDoor_Openening  10DYFan_Flap  10DYExtra_Heater_Offset
# 3                     1            30                        0
# 4                     1            29                        0
# 5                     1            38                        0
# 6                     1            29                        0
# 8                     1            29                        0
# ..                  ...           ...                      ...
# 149                   0             0                        0
# 150                   0             0                        0
# 151                   0             0                        0
# 152                   0            37                        0
# 153                   0            34                        0
#
# [94 rows x 37 columns]

# %%
df_ver_3.columns
# Out:
# Index(['1PWClosed_Cycle_Period', '1PWPeriod', '1PWCirculation_Period',
#        '1PWWaterInlet', '1PWRPM', '1PWTemperature',
#        '1PWLower_Spray_Circulation_Period', '1PWTop_Spray_Circulation_Period',
#        '1PWWaiting', '2MWClosed_Cycle_Period', '2MWPeriod', '2MWWaterInlet',
#        '2MWRPM', '2MWTemperature', '2MWLower_Spray_Circulation_Period',
#        '2MWTop_Spray_Circulation_Period', '3MFPeriod', '4CRPeriod',
#        '4CRWaterInlet', '4CRRPM', '4CRLower_Spray_Circulation_Period',
#        '4CRUpper_Spray_Circulation_Period', '4CRTop_Spray_Circulation_Period',
#        '7RSClosed_Cycle_Period', '7RSPeriod', '7RSRPM', '7RSTemperature',
#        '7RSLower_Spray_Circulation_Period',
#        '7RSUpper_Spray_Circulation_Period', '8DSClosed_Cycle_Period', '8DSRPM',
#        '10DYPeriod', '10DYWaiting', '10DYFan', '10DYDoor_Openening',
#        '10DYFan_Flap', '10DYExtra_Heater_Offset'],
#       dtype='object')

# %%
apt.columns
# Out:
# Index(['1PWRPM', '1PWLower_Spray_Circulation_Period', '1PWWaterInlet',
#        '2MWLower_Spray_Circulation_Period', '2MWPeriod',
#        '4CRUpper_Spray_Circulation_Period', '10DYPeriod'],
#       dtype='object')

# %%
y=y_CPI
variables=['1PWRPM', '1PWLower_Spray_Circulation_Period', '1PWWaterInlet',
       '2MWLower_Spray_Circulation_Period', '2MWPeriod',
       '4CRUpper_Spray_Circulation_Period', '10DYPeriod']
XX=df_ver_3[variables]
model=GradientBoostingRegressor(learning_rate = 0.1, n_estimators = 100, max_depth = 4)
model.fit(XX, y)
# Out:
# GradientBoostingRegressor(max_depth=4)

# %%
apt_ref=apt[variables]

# %%
y_pred_CPI = model.predict(apt)
y_pred_CPI= pd.DataFrame(y_pred_CPI)
apt_ref['outputCPI']=y_pred_CPI

# %%
y_pred_CPI.describe()
# Out:
#                   0
# count  48600.000000
# mean       3.570437
# std        0.020922
# min        3.522683
# 25%        3.553755
# 50%        3.569789
# 75%        3.586406
# max        3.625789

# %%
apt=apt[variables]
y=y_DPI
variables=['1PWRPM', '1PWLower_Spray_Circulation_Period', '1PWWaterInlet',
       '2MWLower_Spray_Circulation_Period', '2MWPeriod',
       '4CRUpper_Spray_Circulation_Period', '10DYPeriod']
XX=df_ver_3[variables]
model=GradientBoostingRegressor(learning_rate = 0.1, n_estimators = 100, max_depth = 4)
model.fit(XX, y)
# Out:
# GradientBoostingRegressor(max_depth=4)

# %%
y_pred_DPI = model.predict(apt)
y_pred_DPI= pd.DataFrame(y_pred_DPI)
apt_ref['outputDPI']=y_pred_DPI

# %%
y_pred_DPI.describe()
# Out:
#                   0
# count  48600.000000
# mean      84.768457
# std        0.548966
# min       83.386619
# 25%       84.364168
# 50%       84.784261
# 75%       85.208185
# max       85.926764

# %%
apt_ref
# Out:
#       1PWRPM 1PWLower_Spray_Circulation_Period  1PWWaterInlet  \
# 0       3200                                32            5.5
# 1       3200                                32            5.5
# 2       3200                                32            5.5
# 3       3200                                32            5.5
# 4       3200                                32            5.5
# ...      ...                               ...            ...
# 48595   2400                                22            4.4
# 48596   2400                                22            4.4
# 48597   2400                                22            4.4
# 48598   2400                                22            4.4
# 48599   2400                                22            4.4
#
#       2MWLower_Spray_Circulation_Period 2MWPeriod  \
# 0                                    45        50
# 1                                    45        50
# 2                                    45        50
# 3                                    45        50
# 4                                    45        50
# ...                                 ...       ...
# 48595                                30        40
# 48596                                30        40
# 48597                                30        40
# 48598                                30        40
# 48599                                30        40
#
#       4CRUpper_Spray_Circulation_Period 10DYPeriod  outputCPI  outputDPI
# 0                                    15         80   3.548591  85.066501
# 1                                    15         60   3.569434  85.424829
# 2                                    15         50   3.566697  85.424829
# 3                                    15         45   3.550856  84.942029
# 4                                    15         43   3.550856  84.942029
# ...                                 ...        ...        ...        ...
# 48595                                 5         60   3.598592  84.327860
# 48596                                 5         50   3.595855  84.276502
# 48597                                 5         45   3.580015  83.930989
# 48598                                 5         43   3.580015  83.930989
# 48599                                 5         41   3.580015  83.930989
#
# [48600 rows x 9 columns]

# %%
filtered_apt = apt_ref[apt_ref['outputCPI'] >= 3.625] 
print(filtered_apt)
# Out:
#       1PWRPM 1PWLower_Spray_Circulation_Period  1PWWaterInlet  \
# 1507    3200                                32            4.4
# 1525    3200                                32            4.4
# 1597    3200                                32            4.4
# 1615    3200                                32            4.4
# 3127    3200                                30            4.4
# 3145    3200                                30            4.4
# 3217    3200                                30            4.4
# 3235    3200                                30            4.4
# 4747    3200                                28            4.4
# 4765    3200                                28            4.4
# 4837    3200                                28            4.4
# 4855    3200                                28            4.4
# 6367    3200                                26            4.4
# 6385    3200                                26            4.4
# 6457    3200                                26            4.4
# 6475    3200                                26            4.4
# 7987    3200                                24            4.4
# 8005    3200                                24            4.4
# 8077    3200                                24            4.4
# 8095    3200                                24            4.4
# 9607    3200                                22            4.4
# 9625    3200                                22            4.4
# 9697    3200                                22            4.4
# 9715    3200                                22            4.4
# 11227   3000                                32            4.4
# 11245   3000                                32            4.4
# 11317   3000                                32            4.4
# 11335   3000                                32            4.4
# 12847   3000                                30            4.4
# 12865   3000                                30            4.4
# 12937   3000                                30            4.4
# 12955   3000                                30            4.4
# 14467   3000                                28            4.4
# 14485   3000                                28            4.4
# 14557   3000                                28            4.4
# 14575   3000                                28            4.4
# 16087   3000                                26            4.4
# 16105   3000                                26            4.4
# 16177   3000                                26            4.4
# 16195   3000                                26            4.4
# 17707   3000                                24            4.4
# 17725   3000                                24            4.4
# 17797   3000                                24            4.4
# 17815   3000                                24            4.4
# 19327   3000                                22            4.4
# 19345   3000                                22            4.4
# 19417   3000                                22            4.4
# 19435   3000                                22            4.4
#
#       2MWLower_Spray_Circulation_Period 2MWPeriod  \
# 1507                                 32        42
# 1525                                 32        40
# 1597                                 30        42
# 1615                                 30        40
# 3127                                 32        42
# 3145                                 32        40
# 3217                                 30        42
# 3235                                 30        40
# 4747                                 32        42
# 4765                                 32        40
# 4837                                 30        42
# 4855                                 30        40
# 6367                                 32        42
# 6385                                 32        40
# 6457                                 30        42
# 6475                                 30        40
# 7987                                 32        42
# 8005                                 32        40
# 8077                                 30        42
# 8095                                 30        40
# 9607                                 32        42
# 9625                                 32        40
# 9697                                 30        42
# 9715                                 30        40
# 11227                                32        42
# 11245                                32        40
# 11317                                30        42
# 11335                                30        40
# 12847                                32        42
# 12865                                32        40
# 12937                                30        42
# 12955                                30        40
# 14467                                32        42
# 14485                                32        40
# 14557                                30        42
# 14575                                30        40
# 16087                                32        42
# 16105                                32        40
# 16177                                30        42
# 16195                                30        40
# 17707                                32        42
# 17725                                32        40
# 17797                                30        42
# 17815                                30        40
# 19327                                32        42
# 19345                                32        40
# 19417                                30        42
# 19435                                30        40
#
#       4CRUpper_Spray_Circulation_Period 10DYPeriod  outputCPI  outputDPI
# 1507                                  5         60   3.625789  84.605378
# 1525                                  5         60   3.625789  84.605378
# 1597                                  5         60   3.625257  84.947704
# 1615                                  5         60   3.625257  84.947704
# 3127                                  5         60   3.625789  84.605378
# 3145                                  5         60   3.625789  84.605378
# 3217                                  5         60   3.625257  84.947704
# 3235                                  5         60   3.625257  84.947704
# 4747                                  5         60   3.625789  84.605378
# 4765                                  5         60   3.625789  84.605378
# 4837                                  5         60   3.625257  84.947704
# 4855                                  5         60   3.625257  84.947704
# 6367                                  5         60   3.625789  84.605378
# 6385                                  5         60   3.625789  84.605378
# 6457                                  5         60   3.625257  84.947704
# 6475                                  5         60   3.625257  84.947704
# 7987                                  5         60   3.625789  84.605378
# 8005                                  5         60   3.625789  84.605378
# 8077                                  5         60   3.625257  84.947704
# 8095                                  5         60   3.625257  84.947704
# 9607                                  5         60   3.625789  84.605378
# 9625                                  5         60   3.625789  84.605378
# 9697                                  5         60   3.625257  84.947704
# 9715                                  5         60   3.625257  84.947704
# 11227                                 5         60   3.625789  84.605378
# 11245                                 5         60   3.625789  84.605378
# 11317                                 5         60   3.625257  84.947704
# 11335                                 5         60   3.625257  84.947704
# 12847                                 5         60   3.625789  84.605378
# 12865                                 5         60   3.625789  84.605378
# 12937                                 5         60   3.625257  84.947704
# 12955                                 5         60   3.625257  84.947704
# 14467                                 5         60   3.625789  84.605378
# 14485                                 5         60   3.625789  84.605378
# 14557                                 5         60   3.625257  84.947704
# 14575                                 5         60   3.625257  84.947704
# 16087                                 5         60   3.625789  84.605378
# 16105                                 5         60   3.625789  84.605378
# 16177                                 5         60   3.625257  84.947704
# 16195                                 5         60   3.625257  84.947704
# 17707                                 5         60   3.625789  84.605378
# 17725                                 5         60   3.625789  84.605378
# 17797                                 5         60   3.625257  84.947704
# 17815                                 5         60   3.625257  84.947704
# 19327                                 5         60   3.625789  84.605378
# 19345                                 5         60   3.625789  84.605378
# 19417                                 5         60   3.625257  84.947704
# 19435                                 5         60   3.625257  84.947704
